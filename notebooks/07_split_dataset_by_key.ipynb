# %%
from src.utils.notebook_setup import *
import src.utils.notebook_ploting as nb_plot
import src.utils.features as features
from src.flows.flow_matching import split_by_key_count

setup_pandas()
df = load_dataset()

# %%
df1, df2 = split_by_key_count(df, "flow_key")

# %%
display(df1["label"].value_counts())
display(df1["label"].value_counts(normalize=True) * 100)
# Out:
# label
# BENIGN                        472142
# PortScan                       30124
# DDoS                           13568
# DoS Hulk                       13530
# DoS GoldenEye                   1174
# DoS Slowhttptest                 963
# Bot                              663
# DoS slowloris                    275
# Web Attack  Brute Force         200
# Web Attack  XSS                 124
# SSH-Patator                       10
# Infiltration                       7
# FTP-Patator                        7
# Web Attack  Sql Injection         1
# Name: count, dtype: int64
# label
# BENIGN                       88.62
# PortScan                      5.65
# DDoS                          2.55
# DoS Hulk                      2.54
# DoS GoldenEye                 0.22
# DoS Slowhttptest              0.18
# Bot                           0.12
# DoS slowloris                 0.05
# Web Attack  Brute Force      0.04
# Web Attack  XSS              0.02
# SSH-Patator                   0.00
# ...

# %%
display(df2["label"].value_counts())
display(df2["label"].value_counts(normalize=True) * 100)
# Out:
# label
# BENIGN                        1305067
# DoS Hulk                       146743
# PortScan                       128492
# DDoS                            61750
# DoS GoldenEye                    7166
# DoS slowloris                    7031
# DoS Slowhttptest                 6293
# Web Attack  Brute Force          974
# Bot                               537
# Web Attack  XSS                  487
# SSH-Patator                        53
# Infiltration                       43
# FTP-Patator                        31
# Web Attack  Sql Injection          2
# Name: count, dtype: int64
# label
# BENIGN                       78.40
# DoS Hulk                      8.82
# PortScan                      7.72
# DDoS                          3.71
# DoS GoldenEye                 0.43
# DoS slowloris                 0.42
# DoS Slowhttptest              0.38
# Web Attack  Brute Force      0.06
# Bot                           0.03
# Web Attack  XSS              0.03
# ...
