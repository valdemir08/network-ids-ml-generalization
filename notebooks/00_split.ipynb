# %%
from src.utils.notebook_setup import *
setup_pandas()

# %%
df_cic = load_dataset("cicids2017")

# %%
df_unsw = load_dataset("unsw_nb15")

# %%
df_iot = load_dataset("iot23")

# %%
display(df_cic.shape)
# Out:
# (336415, 94)

# %%
display(df_unsw.shape)
# Out:
# (336415, 92)

# %%
display(df_iot.shape)
# Out:
# (336415, 94)
