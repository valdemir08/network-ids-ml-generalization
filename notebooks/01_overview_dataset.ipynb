# %%
from src.configs.paths import PROCESSED_DATA_DIR
from src.io.io_utils import load_parquet
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.expand_frame_repr', False)

# %%
path_dataset = PROCESSED_DATA_DIR / "cicids2017/friday.parquet"
df = load_parquet(path_dataset)

# %%
display(df.shape)
df.info(verbose=True)# false para visão mais enxuta
# Out:
# (549856, 79)
# <class 'pandas.DataFrame'>
# Index: 549856 entries, 42 to 767048
# Data columns (total 79 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   id                            549856 non-null  int64
#  1   expiration_id                 549856 non-null  int64
#  2   src_ip                        549856 non-null  str
#  3   src_mac                       549856 non-null  str
#  4   src_oui                       549856 non-null  str
#  5   src_port                      549856 non-null  int64
#  6   dst_ip                        549856 non-null  str
#  7   dst_mac                       549856 non-null  str
#  8   dst_oui                       549856 non-null  str
#  9   dst_port                      549856 non-null  int64
#  10  protocol                      549856 non-null  int64
#  11  ip_version                    549856 non-null  int64
# ...

# %%
display(df.head())
# Out:
#       id  expiration_id         src_ip            src_mac   src_oui  src_port          dst_ip            dst_mac   dst_oui  dst_port  protocol  ip_version  vlan_id  bidirectional_first_seen_ms  bidirectional_last_seen_ms  bidirectional_duration_ms  bidirectional_packets  bidirectional_bytes  src2dst_first_seen_ms  src2dst_last_seen_ms  src2dst_duration_ms  src2dst_packets  src2dst_bytes  dst2src_first_seen_ms  dst2src_last_seen_ms  dst2src_duration_ms  dst2src_packets  dst2src_bytes  bidirectional_min_ps  bidirectional_mean_ps  bidirectional_stddev_ps  bidirectional_max_ps  src2dst_min_ps  src2dst_mean_ps  src2dst_stddev_ps  src2dst_max_ps  dst2src_min_ps  dst2src_mean_ps  dst2src_stddev_ps  dst2src_max_ps  bidirectional_min_piat_ms  bidirectional_mean_piat_ms  bidirectional_stddev_piat_ms  bidirectional_max_piat_ms  src2dst_min_piat_ms  src2dst_mean_piat_ms  src2dst_stddev_piat_ms  src2dst_max_piat_ms  dst2src_min_piat_ms  dst2src_mean_piat_ms  dst2src_stddev_piat_ms  dst2src_max_pi
# ...

# %%
df["label"].value_counts()
# Out:
# label
# BENIGN      314722
# PortScan    158616
# DDoS         75318
# Bot           1200
# Name: count, dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
#ajustar quantidade de linhas por exibição pd.set_alguma_coisa...
# Out:
# id                              0.0
# expiration_id                   0.0
# src_ip                          0.0
# src_mac                         0.0
# src_oui                         0.0
# src_port                        0.0
# dst_ip                          0.0
# dst_mac                         0.0
# dst_oui                         0.0
# dst_port                        0.0
# protocol                        0.0
# ip_version                      0.0
# vlan_id                         0.0
# bidirectional_first_seen_ms     0.0
# bidirectional_last_seen_ms      0.0
# bidirectional_duration_ms       0.0
# bidirectional_packets           0.0
# bidirectional_bytes             0.0
# src2dst_first_seen_ms           0.0
# src2dst_last_seen_ms            0.0
# src2dst_duration_ms             0.0
# src2dst_packets                 0.0
# src2dst_bytes                   0.0
# dst2src_first_seen_ms           0.0
# dst2src_last_seen_ms            0.0
# dst2src_duration_ms             0.0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe().T
# Out:
#                                  count          mean           std           min           25%           50%           75%           max
# id                            549856.0  3.718562e+05  2.222831e+05  4.200000e+01  1.715505e+05  3.528955e+05  5.747248e+05  7.670480e+05
# expiration_id                 549856.0  5.856079e-04  2.419227e-02  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# src_port                      549856.0  4.655050e+04  1.624065e+04  0.000000e+00  3.971400e+04  5.193600e+04  5.794200e+04  6.553500e+04
# dst_port                      549856.0  2.053028e+03  7.573679e+03  0.000000e+00  5.300000e+01  8.000000e+01  4.430000e+02  6.552500e+04
# protocol                      549856.0  8.900132e+00  4.856969e+00  1.000000e+00  6.000000e+00  6.000000e+00  1.700000e+01  1.320000e+02
# ip_version                    549856.0  4.002430e+00  6.966749e-02  4.000000e+00  4.000000e+00  4.000000e+00  4.000000e+00  6.000000e+00
# ...

# %%
num_cols = df.select_dtypes(include="number").columns
cat_cols = df.select_dtypes(include=["object", "string"]).columns
id_cols = ["flow_key", "flow_key_rev"]
aux_cols = ["ts_ms"]

len(num_cols), len(cat_cols)
# Out:
# (70, 9)

# %%
df["bidirectional_duration_ms"].min(), df["bidirectional_duration_ms"].max()
#aparentemente essa coluna foi dropada em algum momento. melhor usar o tempo do nfstream
# Out:
# (np.int64(0), np.int64(119999))
